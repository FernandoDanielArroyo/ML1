# %%
# Importing packages 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # LOADING DATA

# %%
# loading data  
df_trees_origin = pd.read_csv('trees.csv')
df_trees = df_trees_origin.copy()

# %%
# displaying more columns and rows 
pd.set_option('display.max_row', 150)
pd.set_option('display.max_columns', 50)

# %% [markdown]
# # EXPLORING DATA

# %% [markdown]
# ### Shape, first values, types, value counts, columns

# %%
# Exploring data after removing missing values for 'ANNEDEPLANTATION'

# Data shape 
print(f'DATA SHAPE = {df_trees_origin.shape}')
print("")

# Display first rows 
print('FIRST VALUES')
display(df_trees_origin.sample(5))
print("")

# variable types 
print('Variable Types')
display(df_trees_origin.dtypes)
print("")

# number of data per variable type 
print('number of data per variable type')
display(df_trees_origin.dtypes.value_counts())
print("")

# Column names
print('COLUMN NAMES')
display(df_trees_origin.columns)
print("")
# Out:
# DATA SHAPE = (31610, 32)
#
# FIRST VALUES
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 26698          43484  ESP40022  ESP40022   VEG  VEGETATION     ESP01
# 17692          16467  ESP19840  ESP19840   VEG  VEGETATION     ESP01
# 19954          32267  ESP32964  ESP32964   VEG  VEGETATION     ESP01
# 7624           29150   ESP8054   ESP8054   VEG  VEGETATION     ESP01
# 5612            5854   ESP3500   ESP3500   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE        SOUS_CATEGORIE_DESC CODE_PARENT  \
# 26698          Arbre         ESP065  Arbre d'enceintes fermées    ESP40018
# 17692          Arbre         ESP151            Arbre de voirie     ESP1053
# 19954          Arbre         ESP151            Arbre de voirie     ESP1177
# 7624           Arbre         ESP174    Arbre d'espaces ouverts      ESP447
# 5612           Arbre         ESP065  Arbre d'enceintes fermées      ESP405
#
#                     CODE_PARENT_DESC  ADR_SECTEUR BIEN_REFERENCE GENRE_BOTA  \
# 26698               Ecole Montessori            3        AR40022     Cedrus
# 17692  R L Jouhaux de J Bart au n 88            5        AR19840    Populus
# 19954     C JJaurés Berriat à Dupont            1        AR32964     Cornus
# 7624                     Pl J Racine            5         AR8054     Cercis
# 5612    Ec mat Savane 10 R Ronserail            3         AR3500     Sorbus
#
#              ESPECE VARIETE STADEDEDEVELOPPEMENT  EQUIPE  \
# 26698     atlantica  Glauca         Arbre adulte     NaN
# 17692    canadensis     NaN         Arbre adulte     NaN
# 19954   controversa     NaN          Arbre jeune     NaN
# 7624   siliquastrum     NaN         Arbre adulte     NaN
# 5612      cuspidata     NaN         Arbre adulte     NaN
#
#                                                REMARQUES  ANNEEDEPLANTATION  \
# 26698                                                NaN                NaN
# 17692                                                NaN             1978.0
# 19954                                                NaN             2014.0
# 7624                                                 NaN             2013.0
# 5612   Blessures dues à tailles, vigueur faible, tail...             1983.0
#
#       RAISONDEPLANTATION TRAITEMENTCHENILLES  COURRIER  IDENTIFIANTPLU  \
# 26698                NaN                 NaN       NaN             NaN
# 17692                NaN                 NaN       NaN             NaN
# 19954                NaN                 NaN       NaN             NaN
# 7624                 NaN                 NaN       NaN             NaN
# 5612                 NaN                 NaN       NaN             NaN
#
#       TYPEIMPLANTATIONPLU INTITULEPROTECTIONPLU  ANNEEABATTAGE  ESSOUCHEMENT  \
# 26698                 NaN                   NaN            NaN           NaN
# 17692                 NaN                   NaN            NaN           NaN
# 19954                 NaN                   NaN            NaN           NaN
# 7624                  NaN                   NaN            NaN           NaN
# 5612                  NaN                   NaN            NaN           NaN
#
#        DIAMETREARBRE  CAUSEABATTAGE              COLLECTIVITE  \
# 26698            NaN            NaN         Ville de Grenoble
# 17692            NaN            NaN  Grenoble Alpes Métropole
# 19954            NaN            NaN  Grenoble Alpes Métropole
# 7624             NaN            NaN  Grenoble Alpes Métropole
# 5612             NaN            NaN         Ville de Grenoble
#
#                                                  GeoJSON
# 26698  {"type":"Point","coordinates":[5.7069753330697...
# 17692  {"type":"Point","coordinates":[5.7441783608723...
# 19954  {"type":"Point","coordinates":[5.7175260181705...
# 7624   {"type":"Point","coordinates":[5.7413243740302...
# 5612   {"type":"Point","coordinates":[5.7069727924892...
# Variable Types
# ELEM_POINT_ID              int64
# CODE                      object
# NOM                       object
# GENRE                     object
# GENRE_DESC                object
# CATEGORIE                 object
# CATEGORIE_DESC            object
# SOUS_CATEGORIE            object
# SOUS_CATEGORIE_DESC       object
# CODE_PARENT               object
# CODE_PARENT_DESC          object
# ADR_SECTEUR                int64
# BIEN_REFERENCE            object
# GENRE_BOTA                object
# ESPECE                    object
# VARIETE                   object
# STADEDEDEVELOPPEMENT      object
# EQUIPE                   float64
# REMARQUES                 object
# ANNEEDEPLANTATION        float64
# RAISONDEPLANTATION        object
# TRAITEMENTCHENILLES       object
# COURRIER                 float64
# IDENTIFIANTPLU           float64
# TYPEIMPLANTATIONPLU       object
# INTITULEPROTECTIONPLU     object
# ANNEEABATTAGE            float64
# ESSOUCHEMENT             float64
# DIAMETREARBRE            float64
# CAUSEABATTAGE            float64
# COLLECTIVITE              object
# GeoJSON                   object
# dtype: object
# number of data per variable type
# object     22
# float64     8
# int64       2
# dtype: int64
# COLUMN NAMES
# Index(['ELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE',
#        'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC',
#        'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE',
#        'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT', 'EQUIPE',
#        'REMARQUES', 'ANNEEDEPLANTATION', 'RAISONDEPLANTATION',
#        'TRAITEMENTCHENILLES', 'COURRIER', 'IDENTIFIANTPLU',
#        'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU', 'ANNEEABATTAGE',
#        'ESSOUCHEMENT', 'DIAMETREARBRE', 'CAUSEABATTAGE', 'COLLECTIVITE',
#        'GeoJSON'],
#       dtype='object')

# %% [markdown]
# ### Unique values

# %%
df_trees_origin.nunique()
# delete if = 0 or 1
# Out:
# ELEM_POINT_ID            31610
# CODE                     31610
# NOM                      31610
# GENRE                        1
# GENRE_DESC                   1
# CATEGORIE                    1
# CATEGORIE_DESC               1
# SOUS_CATEGORIE               4
# SOUS_CATEGORIE_DESC          4
# CODE_PARENT               1468
# CODE_PARENT_DESC          1468
# ADR_SECTEUR                  6
# BIEN_REFERENCE           31610
# GENRE_BOTA                 118
# ESPECE                     280
# VARIETE                    217
# STADEDEDEVELOPPEMENT         3
# EQUIPE                       0
# REMARQUES                 3021
# ANNEEDEPLANTATION           65
# RAISONDEPLANTATION           3
# TRAITEMENTCHENILLES          3
# COURRIER                     0
# IDENTIFIANTPLU              45
# TYPEIMPLANTATIONPLU          4
# INTITULEPROTECTIONPLU        3
# ANNEEABATTAGE                0
# ESSOUCHEMENT                 0
# DIAMETREARBRE                0
# CAUSEABATTAGE                0
# COLLECTIVITE                 2
# GeoJSON                  31610
# dtype: int64

# %%
df_trees_origin['SOUS_CATEGORIE_DESC'].value_counts()
# Out:
# ESP174    15288
# ESP151    12328
# ESP065     2407
# ESP187     1587
# Name: SOUS_CATEGORIE, dtype: int64

# %% [markdown]
# ### Descriptive stats

# %%
# Descriptive statistiques 
print('DESCRIPTIVE STATS')
print(display(df_trees_origin.describe(include="all")))
print("")
# Out:
# DESCRIPTIVE STATS
#         ELEM_POINT_ID      CODE       NOM  GENRE  GENRE_DESC CATEGORIE  \
# count    31610.000000     31610     31610  31610       31610     31610
# unique            NaN     31610     31610      1           1         1
# top               NaN  ESP29533  ESP29533    VEG  VEGETATION     ESP01
# freq              NaN         1         1  31610       31610     31610
# mean     19946.769630       NaN       NaN    NaN         NaN       NaN
# std      12384.176995       NaN       NaN    NaN         NaN       NaN
# min          1.000000       NaN       NaN    NaN         NaN       NaN
# 25%       9514.250000       NaN       NaN    NaN         NaN       NaN
# 50%      19118.500000       NaN       NaN    NaN         NaN       NaN
# 75%      28762.750000       NaN       NaN    NaN         NaN       NaN
# max      46070.000000       NaN       NaN    NaN         NaN       NaN
#
#        CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  \
# count           31610          31610                    31610       31610
# unique              1              4                        4        1468
# top             Arbre         ESP174  Arbre d'espaces ouverts      ESP995
# freq            31610          15288                    15288         391
# mean              NaN            NaN                      NaN         NaN
# std               NaN            NaN                      NaN         NaN
# min               NaN            NaN                      NaN         NaN
# 25%               NaN            NaN                      NaN         NaN
# 50%               NaN            NaN                      NaN         NaN
# 75%               NaN            NaN                      NaN         NaN
# max               NaN            NaN                      NaN         NaN
#
#                       CODE_PARENT_DESC   ADR_SECTEUR BIEN_REFERENCE  \
# count                            31610  31610.000000          31610
# unique                            1468           NaN          31610
# top     Prc Echangeurs Bastion St Roch           NaN        AR29533
# freq                               391           NaN              1
# mean                               NaN      3.836982            NaN
# std                                NaN      1.717947            NaN
# min                                NaN      1.000000            NaN
# 25%                                NaN      2.000000            NaN
# 50%                                NaN      4.000000            NaN
# 75%                                NaN      5.000000            NaN
# max                                NaN      6.000000            NaN
#
#        GENRE_BOTA      ESPECE    VARIETE STADEDEDEVELOPPEMENT  EQUIPE  \
# count       30818       29146       4569                28408     0.0
# unique        118         280        217                    3     NaN
# top          Acer  acerifolia  Austriaca         Arbre adulte     NaN
# freq         5091        3789       1121                21579     NaN
# mean          NaN         NaN        NaN                  NaN     NaN
# std           NaN         NaN        NaN                  NaN     NaN
# min           NaN         NaN        NaN                  NaN     NaN
# 25%           NaN         NaN        NaN                  NaN     NaN
# 50%           NaN         NaN        NaN                  NaN     NaN
# 75%           NaN         NaN        NaN                  NaN     NaN
# max           NaN         NaN        NaN                  NaN     NaN
#
#        REMARQUES  ANNEEDEPLANTATION RAISONDEPLANTATION TRAITEMENTCHENILLES  \
# count       5307       30258.000000               3260                2138
# unique      3021                NaN                  3                   3
# top       Lierre                NaN            Nouveau               Haute
# freq         165                NaN               2860                1130
# mean         NaN        1989.682563                NaN                 NaN
# std          NaN          17.872479                NaN                 NaN
# min          NaN        1900.000000                NaN                 NaN
# 25%          NaN        1975.000000                NaN                 NaN
# 50%          NaN        1986.000000                NaN                 NaN
# 75%          NaN        2005.000000                NaN                 NaN
# max          NaN        2021.000000                NaN                 NaN
#
#         COURRIER  IDENTIFIANTPLU TYPEIMPLANTATIONPLU INTITULEPROTECTIONPLU  \
# count        0.0      600.000000                 600                   600
# unique       NaN             NaN                   4                     3
# top          NaN             NaN          Alignement             L 123-1.7
# freq         NaN             NaN                 462                   436
# mean         NaN       87.856667                 NaN                   NaN
# std          NaN       60.657935                 NaN                   NaN
# min          NaN        2.000000                 NaN                   NaN
# 25%          NaN       67.000000                 NaN                   NaN
# 50%          NaN       70.000000                 NaN                   NaN
# 75%          NaN       70.000000                 NaN                   NaN
# max          NaN      358.000000                 NaN                   NaN
#
#         ANNEEABATTAGE  ESSOUCHEMENT  DIAMETREARBRE  CAUSEABATTAGE  \
# count             0.0           0.0            0.0            0.0
# unique            NaN           NaN            NaN            NaN
# top               NaN           NaN            NaN            NaN
# freq              NaN           NaN            NaN            NaN
# mean              NaN           NaN            NaN            NaN
# std               NaN           NaN            NaN            NaN
# min               NaN           NaN            NaN            NaN
# 25%               NaN           NaN            NaN            NaN
# 50%               NaN           NaN            NaN            NaN
# 75%               NaN           NaN            NaN            NaN
# max               NaN           NaN            NaN            NaN
#
#              COLLECTIVITE                                            GeoJSON
# count               31139                                              31610
# unique                  2                                              31610
# top     Ville de Grenoble  {"type":"Point","coordinates":[5.7330521059871...
# freq                16105                                                  1
# mean                  NaN                                                NaN
# std                   NaN                                                NaN
# min                   NaN                                                NaN
# 25%                   NaN                                                NaN
# 50%                   NaN                                                NaN
# 75%                   NaN                                                NaN
# max                   NaN                                                NaN
# None

# %% [markdown]
# ### Missing values distribution

# %%
# number of missing values per varible 
print('number of missing values per varible')
print(df_trees_origin.isna().sum())
print("")

# percentage of missing values per variable
print('percentage of missing values per variable')
(df_trees_origin.isna().sum()/len(df_trees_origin)).sort_values()
# Out:
# number of missing values per varible
# ELEM_POINT_ID                0
# CODE                         0
# NOM                          0
# GENRE                        0
# GENRE_DESC                   0
# CATEGORIE                    0
# CATEGORIE_DESC               0
# SOUS_CATEGORIE               0
# SOUS_CATEGORIE_DESC          0
# CODE_PARENT                  0
# CODE_PARENT_DESC             0
# ADR_SECTEUR                  0
# BIEN_REFERENCE               0
# GENRE_BOTA                 792
# ESPECE                    2464
# VARIETE                  27041
# STADEDEDEVELOPPEMENT      3202
# EQUIPE                   31610
# REMARQUES                26303
# ANNEEDEPLANTATION         1352
# RAISONDEPLANTATION       28350
# TRAITEMENTCHENILLES      29472
# COURRIER                 31610
# IDENTIFIANTPLU           31010
# TYPEIMPLANTATIONPLU      31010
# INTITULEPROTECTIONPLU    31010
# ANNEEABATTAGE            31610
# ESSOUCHEMENT             31610
# DIAMETREARBRE            31610
# CAUSEABATTAGE            31610
# COLLECTIVITE               471
# GeoJSON                      0
# dtype: int64
#
# percentage of missing values per variable
# ELEM_POINT_ID            0.000000
# BIEN_REFERENCE           0.000000
# ADR_SECTEUR              0.000000
# CODE_PARENT_DESC         0.000000
# CODE_PARENT              0.000000
# SOUS_CATEGORIE_DESC      0.000000
# SOUS_CATEGORIE           0.000000
# GeoJSON                  0.000000
# CATEGORIE                0.000000
# GENRE_DESC               0.000000
# GENRE                    0.000000
# NOM                      0.000000
# CODE                     0.000000
# CATEGORIE_DESC           0.000000
# COLLECTIVITE             0.014900
# GENRE_BOTA               0.025055
# ANNEEDEPLANTATION        0.042771
# ESPECE                   0.077950
# STADEDEDEVELOPPEMENT     0.101297
# REMARQUES                0.832110
# VARIETE                  0.855457
# RAISONDEPLANTATION       0.896868
# TRAITEMENTCHENILLES      0.932363
# IDENTIFIANTPLU           0.981019
# TYPEIMPLANTATIONPLU      0.981019
# INTITULEPROTECTIONPLU    0.981019
# EQUIPE                   1.000000
# COURRIER                 1.000000
# ANNEEABATTAGE            1.000000
# ESSOUCHEMENT             1.000000
# DIAMETREARBRE            1.000000
# CAUSEABATTAGE            1.000000
# dtype: float64

# %% [markdown]
# # VARIABLE DISTRIBUTION

# %% [markdown]
# ### Seeing target variable distribution

# %%
# Visualising target variable 
plt.figure(figsize=(12,7))
plt.hist(df_trees_origin['ANNEEDEPLANTATION'], bins=121)
plt.show()

# %%
# Visualising GENRE_BOTA variable 
print(df_trees_origin['ANNEEDEPLANTATION'].value_counts())
df_trees_origin['ANNEEDEPLANTATION'].value_counts().plot.bar(figsize=(21,10))
# Out:
# 1975.0    3530
# 2001.0    1483
# 1980.0    1409
# 1970.0    1354
# 2015.0    1008
# 1976.0     891
# 2014.0     887
# 2018.0     869
# 1985.0     859
# 1978.0     841
# 1995.0     734
# 1965.0     730
# 1960.0     702
# 1987.0     691
# 1984.0     646
# 2009.0     641
# 2017.0     608
# 1977.0     601
# 1981.0     596
# 2006.0     580
# 1999.0     562
# 2016.0     531
# 2011.0     491
# 2010.0     450
# 2000.0     416
# 1950.0     401
# 2005.0     382
# 1982.0     355
# 1996.0     353
# 2004.0     341
# 2003.0     338
# 1972.0     318
# 2002.0     316
# 1979.0     316
# 2013.0     315
# 1969.0     314
# 2012.0     309
# 1989.0     298
# 1974.0     286
# 1983.0     285
# 2019.0     279
# 1994.0     248
# 1990.0     240
# 1988.0     230
# 1997.0     230
# 1992.0     218
# 2008.0     211
# 1986.0     210
# 1998.0     205
# 2020.0     173
# 1991.0     139
# 2007.0     135
# 1993.0     134
# 1955.0     116
# 1968.0     111
# 1966.0      85
# 1971.0      67
# 1967.0      52
# 1900.0      42
# 1973.0      33
# 1944.0      26
# 1959.0      16
# 1924.0      11
# 1964.0       6
# 2021.0       4
# Name: ANNEEDEPLANTATION, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ### Categorical variable distributions

# %%
# Visualising GENRE_BOTA variable 
print(df_trees_origin['GENRE_BOTA'].value_counts())
df_trees_origin['GENRE_BOTA'].value_counts().plot.bar(figsize=(21,10))
# Out:
# Acer               5091
# Platanus           4503
# Pinus              1951
# Tilia              1727
# Fraxinus           1514
# Carpinus           1205
# Prunus             1180
# Betula             1105
# Quercus             844
# Liquidambar         815
# Populus             794
# Alnus               776
# Pyrus               614
# Magnolia            510
# Liriodendron        508
# Aesculus            456
# Sophora             425
# Cedrus              414
# Gleditsia           389
# Chamaecyparis       364
# Malus               351
# Cercis              335
# Koelreuteria        299
# Fagus               287
# Zelkova             282
# Picea               258
# Robinia             247
# Celtis              235
# Ulmus               230
# Corylus             205
# Taxus               201
# Cupressus           195
# Amélanchier         140
# Salix               133
# Ginkgo              112
# Crataegus           105
# Ostrya              103
# Catalpa             102
# Paulownia            98
# Morus                98
# Cupressocyparis      96
# Sorbus               96
# Metasequoia          83
# Tetradium            80
# Juglans              76
# Ailanthus            75
# Chionanthus          74
# Parrotia             68
# Lagerstroemia        66
# Pterocarya           58
# Albizia              56
# Cedrela              54
# Thuja                48
# Syringa              43
# Cladastris           42
# Libocedrus           42
# Sambucus             33
# Ficus                30
# Ilex                 27
# Ligustrum            27
# Cornus               26
# Broussonetia         26
# Abies                25
# Trachycarpus         23
# Diospyros            23
# Cydonia              19
# Phellodendron        16
# Eleagnus             14
# Cercidiphyllum       14
# Pteroceltis          13
# Buxus                12
# Maclura              12
# Halesia              11
# Taxodium             11
# Gymnocladus          11
# Sequoiadendron       10
# Pistacia             10
# Laburnum              9
# Mespilus              9
# Photinia              9
# Rhus                  8
# Cotinus               8
# Olea                  8
# Davidia               8
# Chitalpa              7
# Fontanesia            6
# Lonicera              6
# Pterostyrax           6
# Carya                 6
# Sequoia               6
# Calocedrus            6
# Larix                 5
# Clerodendron          5
# Idesia                5
# Punica                4
# Ptelea                4
# Juniperus             4
# Euodia                3
# Styrax                3
# Chimonanthus          3
# Eriobotrya            3
# Hibiscus              3
# Cephalotaxus          3
# Pseudotsuga           2
# Hovenia               2
# Cryptomeria           2
# Araucaria             2
# Phillyrea             2
# Sterculia             1
# Castanea              1
# Poncinos              1
# Nyssa                 1
# Rhamnus               1
# Staphylea             1
# Eucalyptus            1
# Sorbopyrus            1
# Laurus                1
# Acacia                1
# Name: GENRE_BOTA, dtype: int64
# <AxesSubplot:>

# %%
# Visualising ESPECE variable 
print(df_trees_origin['ESPECE'].value_counts())
df_trees_origin['ESPECE'].value_counts().plot.bar(figsize=(25,10))
# Out:
# acerifolia        3789
# nigra             1835
# pseudoplatanus    1297
# betulus           1183
# platanoides       1002
#                   ...
# sativa               1
# foetida              1
# strobus              1
# pisifera             1
# crenata              1
# Name: ESPECE, Length: 280, dtype: int64
# <AxesSubplot:>

# %%
# Visualising GENRE_BOTA variable 
print(df_trees_origin['STADEDEDEVELOPPEMENT'].value_counts())
df_trees_origin['STADEDEDEVELOPPEMENT'].value_counts().plot.bar(figsize=(21,10))
# Out:
# Arbre adulte          21579
# Arbre jeune            6114
# Arbre vieillissant      715
# Name: STADEDEDEVELOPPEMENT, dtype: int64
# <AxesSubplot:>

# %%
# Visualising SOUS_CATEGORIE_DESC variable 
print(df_trees_origin['SOUS_CATEGORIE_DESC'].value_counts())
df_trees_origin['SOUS_CATEGORIE_DESC'].value_counts().plot.bar(figsize=(21,10))
# Out:
# Arbre d'espaces ouverts      15288
# Arbre de voirie              12328
# Arbre d'enceintes fermées     2407
# Bois semi naturel             1587
# Name: SOUS_CATEGORIE_DESC, dtype: int64
# <AxesSubplot:>

# %%
# relation between numerical variables 
sn.heatmap(df_trees_origin.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # CLEANING DATA

# %% [markdown]
# ### Deleting missing values

# %%
# deletaing columns with more than 80% of missing values  
df_trees = df_trees[df_trees.columns[df_trees.isna().sum()/len(df_trees) < 0.8]]

# deleting missing data for 'ANNEDEPLANTATION' = df_trees_clean1
df_trees.dropna(subset=['ANNEEDEPLANTATION'], how='any', inplace=True)

# varifying there is no missing values left 
df_trees['ANNEEDEPLANTATION'].isna().sum()
# Out:
# /home/fernando.arroyo@Digital-Grenoble.local/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# 0

# %% [markdown]
# # EXPLORING DATA (AFTER CLEANING)

# %% [markdown]
# ### Shape, first values, types, value counts, columns

# %%
# Exploring data after removing missing values for 'ANNEDEPLANTATION'

# Data shape 
print(f'DATA SHAPE = {df_trees.shape}')
print("")

# Display first rows 
print('FIRST VALUES')
display(df_trees.head(5))
print("")

# variable types 
print('Variable Types')
display(df_trees.dtypes)
print("")

# number of data per variable type 
print('number of data per variable type')
display(df_trees.dtypes.value_counts())
print("")

# Column names
print('COLUMN NAMES')
display(df_trees.columns)
print("")
# Out:
# DATA SHAPE = (30258, 19)
#
# FIRST VALUES
#    ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0          28796  ESP29533  ESP29533   VEG  VEGETATION     ESP01
# 1          28802  ESP29534  ESP29534   VEG  VEGETATION     ESP01
# 2          28805  ESP29535  ESP29535   VEG  VEGETATION     ESP01
# 3          28814  ESP29537  ESP29537   VEG  VEGETATION     ESP01
# 4          24990  ESP29538  ESP29538   VEG  VEGETATION     ESP01
#
#   CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP437
# 1          Arbre         ESP174  Arbre d'espaces ouverts     ESP1393
# 2          Arbre         ESP174  Arbre d'espaces ouverts     ESP1393
# 3          Arbre         ESP174  Arbre d'espaces ouverts      ESP438
# 4          Arbre         ESP151          Arbre de voirie      ESP430
#
#                  CODE_PARENT_DESC  ADR_SECTEUR BIEN_REFERENCE GENRE_BOTA  \
# 0  Tr quartiers talu architecture            6        AR29533      Pinus
# 1      Désserte des alisiers mail            6        AR29534   Platanus
# 2      Désserte des alisiers mail            6        AR29535   Platanus
# 3  La piste pel de l'aire de jeux            6        AR29537   Carpinus
# 4   R Salengro sép Libé Schweitz             3        AR29538     Cercis
#
#          ESPECE STADEDEDEVELOPPEMENT  ANNEEDEPLANTATION  \
# 0           NaN         Arbre adulte             1975.0
# 1    acerifolia         Arbre adulte             1975.0
# 2    acerifolia         Arbre adulte             1975.0
# 3       betulus         Arbre adulte             1975.0
# 4  siliquastrum         Arbre adulte             2006.0
#
#                COLLECTIVITE                                            GeoJSON
# 0         Ville de Grenoble  {"type":"Point","coordinates":[5.7330521059871...
# 1         Ville de Grenoble  {"type":"Point","coordinates":[5.7396645998576...
# 2         Ville de Grenoble  {"type":"Point","coordinates":[5.7393760050367...
# 3         Ville de Grenoble  {"type":"Point","coordinates":[5.7327578896097...
# 4  Grenoble Alpes Métropole  {"type":"Point","coordinates":[5.7101806683940...
# Variable Types
# ELEM_POINT_ID             int64
# CODE                     object
# NOM                      object
# GENRE                    object
# GENRE_DESC               object
# CATEGORIE                object
# CATEGORIE_DESC           object
# SOUS_CATEGORIE           object
# SOUS_CATEGORIE_DESC      object
# CODE_PARENT              object
# CODE_PARENT_DESC         object
# ADR_SECTEUR               int64
# BIEN_REFERENCE           object
# GENRE_BOTA               object
# ESPECE                   object
# STADEDEDEVELOPPEMENT     object
# ANNEEDEPLANTATION       float64
# COLLECTIVITE             object
# GeoJSON                  object
# dtype: object
# number of data per variable type
# object     16
# int64       2
# float64     1
# dtype: int64
# COLUMN NAMES
# Index(['ELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE',
#        'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC',
#        'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE',
#        'GENRE_BOTA', 'ESPECE', 'STADEDEDEVELOPPEMENT', 'ANNEEDEPLANTATION',
#        'COLLECTIVITE', 'GeoJSON'],
#       dtype='object')

# %% [markdown]
# ### Descriptive stats

# %%
# Descriptive statistiques 
print('DESCRIPTIVE STATS')
print(display(df_trees.describe(include="all")))
print("")
# Out:
# DESCRIPTIVE STATS
#         ELEM_POINT_ID      CODE       NOM  GENRE  GENRE_DESC CATEGORIE  \
# count    30258.000000     30258     30258  30258       30258     30258
# unique            NaN     30258     30258      1           1         1
# top               NaN  ESP29533  ESP29533    VEG  VEGETATION     ESP01
# freq              NaN         1         1  30258       30258     30258
# mean     18895.751900       NaN       NaN    NaN         NaN       NaN
# std      11580.271779       NaN       NaN    NaN         NaN       NaN
# min          1.000000       NaN       NaN    NaN         NaN       NaN
# 25%       9117.250000       NaN       NaN    NaN         NaN       NaN
# 50%      18292.500000       NaN       NaN    NaN         NaN       NaN
# 75%      27535.750000       NaN       NaN    NaN         NaN       NaN
# max      45450.000000       NaN       NaN    NaN         NaN       NaN
#
#        CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  \
# count           30258          30258                    30258       30258
# unique              1              4                        4        1458
# top             Arbre         ESP174  Arbre d'espaces ouverts      ESP995
# freq            30258          14833                    14833         391
# mean              NaN            NaN                      NaN         NaN
# std               NaN            NaN                      NaN         NaN
# min               NaN            NaN                      NaN         NaN
# 25%               NaN            NaN                      NaN         NaN
# 50%               NaN            NaN                      NaN         NaN
# 75%               NaN            NaN                      NaN         NaN
# max               NaN            NaN                      NaN         NaN
#
#                       CODE_PARENT_DESC   ADR_SECTEUR BIEN_REFERENCE  \
# count                            30258  30258.000000          30258
# unique                            1458           NaN          30258
# top     Prc Echangeurs Bastion St Roch           NaN        AR29533
# freq                               391           NaN              1
# mean                               NaN      3.829136            NaN
# std                                NaN      1.709151            NaN
# min                                NaN      1.000000            NaN
# 25%                                NaN      2.000000            NaN
# 50%                                NaN      4.000000            NaN
# 75%                                NaN      5.000000            NaN
# max                                NaN      6.000000            NaN
#
#        GENRE_BOTA      ESPECE STADEDEDEVELOPPEMENT  ANNEEDEPLANTATION  \
# count       30233       28740                28090       30258.000000
# unique        117         273                    3                NaN
# top          Acer  acerifolia         Arbre adulte                NaN
# freq         5017        3754                21354                NaN
# mean          NaN         NaN                  NaN        1989.682563
# std           NaN         NaN                  NaN          17.872479
# min           NaN         NaN                  NaN        1900.000000
# 25%           NaN         NaN                  NaN        1975.000000
# 50%           NaN         NaN                  NaN        1986.000000
# 75%           NaN         NaN                  NaN        2005.000000
# max           NaN         NaN                  NaN        2021.000000
#
#              COLLECTIVITE                                            GeoJSON
# count               30258                                              30258
# unique                  2                                              30258
# top     Ville de Grenoble  {"type":"Point","coordinates":[5.7330521059871...
# freq                15651                                                  1
# mean                  NaN                                                NaN
# std                   NaN                                                NaN
# min                   NaN                                                NaN
# 25%                   NaN                                                NaN
# 50%                   NaN                                                NaN
# 75%                   NaN                                                NaN
# max                   NaN                                                NaN
# None

# %% [markdown]
# ### Missing values distribution

# %%
# Exploring missing data after ANNEEDEPLANTATION's missing values supression 

# number of missing values per varible 
print('number of missing values per varible')
print(df_trees.isna().sum())
print("")

# percentage of missing values per variable
print('percentage of missing values per variable')
(df_trees.isna().sum()/len(df_trees)).sort_values()
# Out:
# number of missing values per varible
# ELEM_POINT_ID              0
# CODE                       0
# NOM                        0
# GENRE                      0
# GENRE_DESC                 0
# CATEGORIE                  0
# CATEGORIE_DESC             0
# SOUS_CATEGORIE             0
# SOUS_CATEGORIE_DESC        0
# CODE_PARENT                0
# CODE_PARENT_DESC           0
# ADR_SECTEUR                0
# BIEN_REFERENCE             0
# GENRE_BOTA                25
# ESPECE                  1518
# STADEDEDEVELOPPEMENT    2168
# ANNEEDEPLANTATION          0
# COLLECTIVITE               0
# GeoJSON                    0
# dtype: int64
#
# percentage of missing values per variable
# ELEM_POINT_ID           0.000000
# ANNEEDEPLANTATION       0.000000
# BIEN_REFERENCE          0.000000
# ADR_SECTEUR             0.000000
# CODE_PARENT_DESC        0.000000
# COLLECTIVITE            0.000000
# SOUS_CATEGORIE_DESC     0.000000
# CODE_PARENT             0.000000
# CATEGORIE_DESC          0.000000
# CATEGORIE               0.000000
# GENRE_DESC              0.000000
# GENRE                   0.000000
# NOM                     0.000000
# CODE                    0.000000
# SOUS_CATEGORIE          0.000000
# GeoJSON                 0.000000
# GENRE_BOTA              0.000826
# ESPECE                  0.050169
# STADEDEDEVELOPPEMENT    0.071650
# dtype: float64

# %% [markdown]
# # VARIABLE DISTRIBUTION

# %% [markdown]
# ### Seeing target variable distribution

# %%
# Visualising target variable 
plt.figure(figsize=(12,7))
plt.hist(df_trees['ANNEEDEPLANTATION'], bins=121)
plt.show()

# %%
# Visualising GENRE_BOTA variable 
print(df_trees['ANNEEDEPLANTATION'].value_counts())
df_trees['ANNEEDEPLANTATION'].value_counts().plot.bar(figsize=(21,10))
# Out:
# 1975.0    3530
# 2001.0    1483
# 1980.0    1409
# 1970.0    1354
# 2015.0    1008
# 1976.0     891
# 2014.0     887
# 2018.0     869
# 1985.0     859
# 1978.0     841
# 1995.0     734
# 1965.0     730
# 1960.0     702
# 1987.0     691
# 1984.0     646
# 2009.0     641
# 2017.0     608
# 1977.0     601
# 1981.0     596
# 2006.0     580
# 1999.0     562
# 2016.0     531
# 2011.0     491
# 2010.0     450
# 2000.0     416
# 1950.0     401
# 2005.0     382
# 1982.0     355
# 1996.0     353
# 2004.0     341
# 2003.0     338
# 1972.0     318
# 2002.0     316
# 1979.0     316
# 2013.0     315
# 1969.0     314
# 2012.0     309
# 1989.0     298
# 1974.0     286
# 1983.0     285
# 2019.0     279
# 1994.0     248
# 1990.0     240
# 1988.0     230
# 1997.0     230
# 1992.0     218
# 2008.0     211
# 1986.0     210
# 1998.0     205
# 2020.0     173
# 1991.0     139
# 2007.0     135
# 1993.0     134
# 1955.0     116
# 1968.0     111
# 1966.0      85
# 1971.0      67
# 1967.0      52
# 1900.0      42
# 1973.0      33
# 1944.0      26
# 1959.0      16
# 1924.0      11
# 1964.0       6
# 2021.0       4
# Name: ANNEEDEPLANTATION, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ### Categorical variable distributions

# %%
# Visualising GENRE_BOTA variable 
print(df_trees['GENRE_BOTA'].value_counts())
df_trees['GENRE_BOTA'].value_counts().plot.bar(figsize=(21,10))
# Out:
# Acer               5017
# Platanus           4461
# Pinus              1921
# Tilia              1722
# Fraxinus           1446
# Prunus             1165
# Carpinus           1163
# Betula             1084
# Quercus             837
# Liquidambar         805
# Populus             785
# Alnus               769
# Pyrus               606
# Magnolia            507
# Liriodendron        503
# Aesculus            440
# Sophora             424
# Cedrus              409
# Gleditsia           374
# Chamaecyparis       360
# Cercis              330
# Malus               319
# Koelreuteria        295
# Fagus               280
# Zelkova             280
# Robinia             243
# Picea               231
# Celtis              228
# Ulmus               224
# Taxus               200
# Corylus             197
# Cupressus           184
# Amélanchier         139
# Salix               132
# Ginkgo              112
# Crataegus           104
# Ostrya              103
# Catalpa             102
# Morus                97
# Cupressocyparis      96
# Paulownia            93
# Sorbus               92
# Metasequoia          83
# Tetradium            80
# Ailanthus            73
# Juglans              68
# Parrotia             68
# Chionanthus          64
# Lagerstroemia        64
# Pterocarya           58
# Albizia              56
# Cedrela              49
# Thuja                48
# Syringa              43
# Libocedrus           42
# Cladastris           42
# Sambucus             33
# Ilex                 27
# Broussonetia         26
# Cornus               24
# Abies                24
# Ficus                23
# Trachycarpus         23
# Diospyros            22
# Cydonia              19
# Eleagnus             14
# Phellodendron        14
# Pteroceltis          13
# Buxus                12
# Maclura              11
# Taxodium             11
# Halesia              11
# Cercidiphyllum       11
# Sequoiadendron       10
# Mespilus              9
# Laburnum              9
# Pistacia              9
# Gymnocladus           9
# Photinia              9
# Davidia               8
# Rhus                  8
# Ligustrum             8
# Cotinus               8
# Chitalpa              7
# Olea                  7
# Fontanesia            6
# Sequoia               6
# Lonicera              6
# Pterostyrax           6
# Calocedrus            6
# Larix                 5
# Idesia                5
# Clerodendron          5
# Punica                4
# Ptelea                4
# Juniperus             4
# Styrax                3
# Euodia                3
# Cephalotaxus          3
# Hibiscus              3
# Eriobotrya            3
# Chimonanthus          3
# Carya                 3
# Pseudotsuga           2
# Araucaria             2
# Cryptomeria           2
# Hovenia               2
# Phillyrea             2
# Nyssa                 1
# Rhamnus               1
# Staphylea             1
# Eucalyptus            1
# Castanea              1
# Sterculia             1
# Sorbopyrus            1
# Poncinos              1
# Acacia                1
# Name: GENRE_BOTA, dtype: int64
# <AxesSubplot:>

# %%
# Visualising ESPECE variable 
print(df_trees['ESPECE'].value_counts())
df_trees['ESPECE'].value_counts().plot.bar(figsize=(25,10))
# Out:
# acerifolia        3754
# nigra             1807
# pseudoplatanus    1294
# betulus           1144
# platanoides       1001
#                   ...
# foetida              1
# strobus              1
# pisifera             1
# quadrangulata        1
# monticola            1
# Name: ESPECE, Length: 273, dtype: int64
# <AxesSubplot:>

# %%
# Visualising GENRE_BOTA variable 
print(df_trees['STADEDEDEVELOPPEMENT'].value_counts())
df_trees['STADEDEDEVELOPPEMENT'].value_counts().plot.bar(figsize=(21,10))
# Out:
# Arbre adulte          21354
# Arbre jeune            6028
# Arbre vieillissant      708
# Name: STADEDEDEVELOPPEMENT, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ## Seeing variable relations

# %% [markdown]
# ### Relation between numerical variables

# %%
# relation between numerical variables 
sn.heatmap(df_trees.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## TO PICKLE DATA FRAME

# %%
# to pickle data frame
df_trees.to_pickle('./df_trees.pkl')
