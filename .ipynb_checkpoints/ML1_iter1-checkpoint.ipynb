# %%
# Importing packages 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # LOADING DATA

# %%
# loading data  
df_trees_origin = pd.read_csv('trees.csv')
df_trees = df_trees_origin.copy()

# %%
# displaying more columns and rows 
pd.set_option('display.max_row', 150)
pd.set_option('display.max_columns', 50)

# %% [markdown]
# # EXPLORING DATA

# %% [markdown]
# ### Shape, first values, types, value counts, columns

# %%
# Exploring data after removing missing values for 'ANNEDEPLANTATION'

# Data shape 
print(f'DATA SHAPE = {df_trees_origin.shape}')
print("")

# Display first rows 
print('FIRST VALUES')
display(df_trees_origin.sample(5))
print("")

# variable types 
print('Variable Types')
display(df_trees_origin.dtypes)
print("")

# number of data per variable type 
print('number of data per variable type')
display(df_trees_origin.dtypes.value_counts())
print("")

# Column names
print('COLUMN NAMES')
display(df_trees_origin.columns)
print("")
# Out:
# DATA SHAPE = (31610, 32)
#
# FIRST VALUES
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 16349          15230  ESP18439  ESP18439   VEG  VEGETATION     ESP01
# 3075            8313   ESP2706   ESP2706   VEG  VEGETATION     ESP01
# 9246            2988   ESP9600   ESP9600   VEG  VEGETATION     ESP01
# 31179          38062  ESP38022  ESP38022   VEG  VEGETATION     ESP01
# 15727          19952  ESP17801  ESP17801   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  \
# 16349          Arbre         ESP174  Arbre d'espaces ouverts     ESP1186
# 3075           Arbre         ESP174  Arbre d'espaces ouverts      ESP973
# 9246           Arbre         ESP174  Arbre d'espaces ouverts      ESP902
# 31179          Arbre         ESP151          Arbre de voirie      ESP747
# 15727          Arbre         ESP174  Arbre d'espaces ouverts     ESP1047
#
#                      CODE_PARENT_DESC  ADR_SECTEUR BIEN_REFERENCE GENRE_BOTA  \
# 16349        Trémie tram Sémard talus            1        AR18439      Pinus
# 3075           Jard Hoche pelouse Est            2         AR2706    Populus
# 9246              R Esmonin talus IMT            6         AR9600   Carpinus
# 31179        R Esmonin talus Alibert             6        AR38022       Acer
# 15727  R Arts de montagne face 9 à 13            4        AR17801      Pinus
#
#         ESPECE    VARIETE STADEDEDEVELOPPEMENT  EQUIPE  \
# 16349    nigra  Austriaca         Arbre adulte     NaN
# 3075     nigra    Italica         Arbre adulte     NaN
# 9246   betulus        NaN         Arbre adulte     NaN
# 31179      NaN        NaN                  NaN     NaN
# 15727    nigra  Austriaca         Arbre adulte     NaN
#
#                      REMARQUES  ANNEEDEPLANTATION RAISONDEPLANTATION  \
# 16349  blessure tronc à suivre             2000.0                NaN
# 3075                       NaN             1978.0                NaN
# 9246                       NaN             1980.0                NaN
# 31179                      NaN             2016.0            Nouveau
# 15727                      NaN             1988.0                NaN
#
#       TRAITEMENTCHENILLES  COURRIER  IDENTIFIANTPLU TYPEIMPLANTATIONPLU  \
# 16349               Haute       NaN             NaN                 NaN
# 3075                  NaN       NaN             NaN                 NaN
# 9246                  NaN       NaN             NaN                 NaN
# 31179                 NaN       NaN             NaN                 NaN
# 15727                 NaN       NaN             NaN                 NaN
#
#       INTITULEPROTECTIONPLU  ANNEEABATTAGE  ESSOUCHEMENT  DIAMETREARBRE  \
# 16349                   NaN            NaN           NaN            NaN
# 3075                    NaN            NaN           NaN            NaN
# 9246                    NaN            NaN           NaN            NaN
# 31179                   NaN            NaN           NaN            NaN
# 15727                   NaN            NaN           NaN            NaN
#
#        CAUSEABATTAGE              COLLECTIVITE  \
# 16349            NaN  Grenoble Alpes Métropole
# 3075             NaN         Ville de Grenoble
# 9246             NaN  Grenoble Alpes Métropole
# 31179            NaN  Grenoble Alpes Métropole
# 15727            NaN  Grenoble Alpes Métropole
#
#                                                  GeoJSON
# 16349  {"type":"Point","coordinates":[5.7149261840958...
# 3075   {"type":"Point","coordinates":[5.7283116549503...
# 9246   {"type":"Point","coordinates":[5.7218909037366...
# 31179  {"type":"Point","coordinates":[5.7196225034759...
# 15727  {"type":"Point","coordinates":[5.7176883255324...
# Variable Types
# ELEM_POINT_ID              int64
# CODE                      object
# NOM                       object
# GENRE                     object
# GENRE_DESC                object
# CATEGORIE                 object
# CATEGORIE_DESC            object
# SOUS_CATEGORIE            object
# SOUS_CATEGORIE_DESC       object
# CODE_PARENT               object
# CODE_PARENT_DESC          object
# ADR_SECTEUR                int64
# BIEN_REFERENCE            object
# GENRE_BOTA                object
# ESPECE                    object
# VARIETE                   object
# STADEDEDEVELOPPEMENT      object
# EQUIPE                   float64
# REMARQUES                 object
# ANNEEDEPLANTATION        float64
# RAISONDEPLANTATION        object
# TRAITEMENTCHENILLES       object
# COURRIER                 float64
# IDENTIFIANTPLU           float64
# TYPEIMPLANTATIONPLU       object
# INTITULEPROTECTIONPLU     object
# ANNEEABATTAGE            float64
# ESSOUCHEMENT             float64
# DIAMETREARBRE            float64
# CAUSEABATTAGE            float64
# COLLECTIVITE              object
# GeoJSON                   object
# dtype: object
# number of data per variable type
# object     22
# float64     8
# int64       2
# dtype: int64
# COLUMN NAMES
# Index(['ELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE',
#        'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC',
#        'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE',
#        'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT', 'EQUIPE',
#        'REMARQUES', 'ANNEEDEPLANTATION', 'RAISONDEPLANTATION',
#        'TRAITEMENTCHENILLES', 'COURRIER', 'IDENTIFIANTPLU',
#        'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU', 'ANNEEABATTAGE',
#        'ESSOUCHEMENT', 'DIAMETREARBRE', 'CAUSEABATTAGE', 'COLLECTIVITE',
#        'GeoJSON'],
#       dtype='object')

# %% [markdown]
# ### Descriptive stats

# %%
# Descriptive statistiques 
print('DESCRIPTIVE STATS')
print(display(df_trees.describe(include="all")))
# Out:
# DESCRIPTIVE STATS
#         ELEM_POINT_ID      CODE       NOM SOUS_CATEGORIE  \
# count    31610.000000     31610     31610          31610
# unique            NaN     31610     31610              4
# top               NaN  ESP29533  ESP29533         ESP174
# freq              NaN         1         1          15288
# mean     19946.769630       NaN       NaN            NaN
# std      12384.176995       NaN       NaN            NaN
# min          1.000000       NaN       NaN            NaN
# 25%       9514.250000       NaN       NaN            NaN
# 50%      19118.500000       NaN       NaN            NaN
# 75%      28762.750000       NaN       NaN            NaN
# max      46070.000000       NaN       NaN            NaN
#
#             SOUS_CATEGORIE_DESC CODE_PARENT                CODE_PARENT_DESC  \
# count                     31610       31610                           31610
# unique                        4        1468                            1468
# top     Arbre d'espaces ouverts      ESP995  Prc Echangeurs Bastion St Roch
# freq                      15288         391                             391
# mean                        NaN         NaN                             NaN
# std                         NaN         NaN                             NaN
# min                         NaN         NaN                             NaN
# 25%                         NaN         NaN                             NaN
# 50%                         NaN         NaN                             NaN
# 75%                         NaN         NaN                             NaN
# max                         NaN         NaN                             NaN
#
#          ADR_SECTEUR BIEN_REFERENCE GENRE_BOTA      ESPECE    VARIETE  \
# count   31610.000000          31610      30818       29146       4569
# unique           NaN          31610        118         280        217
# top              NaN        AR29533       Acer  acerifolia  Austriaca
# freq             NaN              1       5091        3789       1121
# mean        3.836982            NaN        NaN         NaN        NaN
# std         1.717947            NaN        NaN         NaN        NaN
# min         1.000000            NaN        NaN         NaN        NaN
# 25%         2.000000            NaN        NaN         NaN        NaN
# 50%         4.000000            NaN        NaN         NaN        NaN
# 75%         5.000000            NaN        NaN         NaN        NaN
# max         6.000000            NaN        NaN         NaN        NaN
#
#        STADEDEDEVELOPPEMENT REMARQUES  ANNEEDEPLANTATION RAISONDEPLANTATION  \
# count                 28408      5307       30258.000000               3260
# unique                    3      3021                NaN                  3
# top            Arbre adulte    Lierre                NaN            Nouveau
# freq                  21579       165                NaN               2860
# mean                    NaN       NaN        1989.682563                NaN
# std                     NaN       NaN          17.872479                NaN
# min                     NaN       NaN        1900.000000                NaN
# 25%                     NaN       NaN        1975.000000                NaN
# 50%                     NaN       NaN        1986.000000                NaN
# 75%                     NaN       NaN        2005.000000                NaN
# max                     NaN       NaN        2021.000000                NaN
#
#        TRAITEMENTCHENILLES  IDENTIFIANTPLU TYPEIMPLANTATIONPLU  \
# count                 2138      600.000000                 600
# unique                   3             NaN                   4
# top                  Haute             NaN          Alignement
# freq                  1130             NaN                 462
# mean                   NaN       87.856667                 NaN
# std                    NaN       60.657935                 NaN
# min                    NaN        2.000000                 NaN
# 25%                    NaN       67.000000                 NaN
# 50%                    NaN       70.000000                 NaN
# 75%                    NaN       70.000000                 NaN
# max                    NaN      358.000000                 NaN
#
#        INTITULEPROTECTIONPLU       COLLECTIVITE  \
# count                    600              31139
# unique                     3                  2
# top                L 123-1.7  Ville de Grenoble
# freq                     436              16105
# mean                     NaN                NaN
# std                      NaN                NaN
# min                      NaN                NaN
# 25%                      NaN                NaN
# 50%                      NaN                NaN
# 75%                      NaN                NaN
# max                      NaN                NaN
#
#                                                   GeoJSON
# count                                               31610
# unique                                              31610
# top     {"type":"Point","coordinates":[5.7330521059871...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# None

# %% [markdown]
# ### Unique values

# %%
df_trees.nunique()
# delete if = 0 or 1
# Out:
# ELEM_POINT_ID            31610
# CODE                     31610
# NOM                      31610
# GENRE                        1
# GENRE_DESC                   1
# CATEGORIE                    1
# CATEGORIE_DESC               1
# SOUS_CATEGORIE               4
# SOUS_CATEGORIE_DESC          4
# CODE_PARENT               1468
# CODE_PARENT_DESC          1468
# ADR_SECTEUR                  6
# BIEN_REFERENCE           31610
# GENRE_BOTA                 118
# ESPECE                     280
# VARIETE                    217
# STADEDEDEVELOPPEMENT         3
# EQUIPE                       0
# REMARQUES                 3021
# ANNEEDEPLANTATION           65
# RAISONDEPLANTATION           3
# TRAITEMENTCHENILLES          3
# COURRIER                     0
# IDENTIFIANTPLU              45
# TYPEIMPLANTATIONPLU          4
# INTITULEPROTECTIONPLU        3
# ANNEEABATTAGE                0
# ESSOUCHEMENT                 0
# DIAMETREARBRE                0
# CAUSEABATTAGE                0
# COLLECTIVITE                 2
# GeoJSON                  31610
# dtype: int64

# %% [markdown]
# ## DROPING UNIQUE VALUES

# %%
# deletaing columns <= 1 unique values  
list_dropcol = []
for i in df_trees.columns[df_trees.nunique()<=1]:
    list_dropcol.append(i)

# columns to drop list 
print(list_dropcol)

# droping columns 
df_trees.drop(list_dropcol, axis=1, inplace=True)
# Out:
# ['GENRE', 'GENRE_DESC', 'CATEGORIE', 'CATEGORIE_DESC', 'EQUIPE', 'COURRIER', 'ANNEEABATTAGE', 'ESSOUCHEMENT', 'DIAMETREARBRE', 'CAUSEABATTAGE']

# %% [markdown]
# ### Missing values distribution

# %%
# number of missing values per varible 
print('number of missing values per varible')
print(df_trees.isna().sum())
print("")

# percentage of missing values per variable
print('percentage of missing values per variable')
(df_trees.isna().sum()/len(df_trees)).sort_values()
# Out:
# number of missing values per varible
# ELEM_POINT_ID                0
# CODE                         0
# NOM                          0
# SOUS_CATEGORIE               0
# SOUS_CATEGORIE_DESC          0
# CODE_PARENT                  0
# CODE_PARENT_DESC             0
# ADR_SECTEUR                  0
# BIEN_REFERENCE               0
# GENRE_BOTA                 792
# ESPECE                    2464
# VARIETE                  27041
# STADEDEDEVELOPPEMENT      3202
# REMARQUES                26303
# ANNEEDEPLANTATION         1352
# RAISONDEPLANTATION       28350
# TRAITEMENTCHENILLES      29472
# IDENTIFIANTPLU           31010
# TYPEIMPLANTATIONPLU      31010
# INTITULEPROTECTIONPLU    31010
# COLLECTIVITE               471
# GeoJSON                      0
# dtype: int64
#
# percentage of missing values per variable
# ELEM_POINT_ID            0.000000
# BIEN_REFERENCE           0.000000
# ADR_SECTEUR              0.000000
# CODE_PARENT_DESC         0.000000
# CODE_PARENT              0.000000
# GeoJSON                  0.000000
# SOUS_CATEGORIE           0.000000
# NOM                      0.000000
# CODE                     0.000000
# SOUS_CATEGORIE_DESC      0.000000
# COLLECTIVITE             0.014900
# GENRE_BOTA               0.025055
# ANNEEDEPLANTATION        0.042771
# ESPECE                   0.077950
# STADEDEDEVELOPPEMENT     0.101297
# REMARQUES                0.832110
# VARIETE                  0.855457
# RAISONDEPLANTATION       0.896868
# TRAITEMENTCHENILLES      0.932363
# IDENTIFIANTPLU           0.981019
# TYPEIMPLANTATIONPLU      0.981019
# INTITULEPROTECTIONPLU    0.981019
# dtype: float64

# %% [markdown]
# ## DROPING MISSING VALUES

# %%
# deletaing columns with more than 80% of missing values  
df_trees = df_trees[df_trees.columns[df_trees.isna().sum()/len(df_trees) < 0.8]]

# deleting missing data for 'ANNEDEPLANTATION' = df_trees_clean1
df_trees.dropna(subset=['ANNEEDEPLANTATION'], how='any', inplace=True)

# varifying there is no missing values left 
df_trees['ANNEEDEPLANTATION'].isna().sum()
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# 0

# %% [markdown]
# ### Missing values distribution (after droping missing values)

# %%
# number of missing values per varible 
print('number of missing values per varible')
print(df_trees.isna().sum())
print("")

# percentage of missing values per variable
print('percentage of missing values per variable')
(df_trees.isna().sum()/len(df_trees)).sort_values()
# Out:
# number of missing values per varible
# ELEM_POINT_ID              0
# CODE                       0
# NOM                        0
# SOUS_CATEGORIE             0
# SOUS_CATEGORIE_DESC        0
# CODE_PARENT                0
# CODE_PARENT_DESC           0
# ADR_SECTEUR                0
# BIEN_REFERENCE             0
# GENRE_BOTA                25
# ESPECE                  1518
# STADEDEDEVELOPPEMENT    2168
# ANNEEDEPLANTATION          0
# COLLECTIVITE               0
# GeoJSON                    0
# dtype: int64
#
# percentage of missing values per variable
# ELEM_POINT_ID           0.000000
# CODE                    0.000000
# NOM                     0.000000
# SOUS_CATEGORIE          0.000000
# SOUS_CATEGORIE_DESC     0.000000
# CODE_PARENT             0.000000
# CODE_PARENT_DESC        0.000000
# ADR_SECTEUR             0.000000
# BIEN_REFERENCE          0.000000
# ANNEEDEPLANTATION       0.000000
# COLLECTIVITE            0.000000
# GeoJSON                 0.000000
# GENRE_BOTA              0.000826
# ESPECE                  0.050169
# STADEDEDEVELOPPEMENT    0.071650
# dtype: float64

# %% [markdown]
# # VARIABLE DISTRIBUTION

# %% [markdown]
# ### Seeing target variable distribution

# %%
# Visualising GENRE_BOTA variable 
# print(df_trees['ANNEEDEPLANTATION'].value_counts())
df_trees['ANNEEDEPLANTATION'].value_counts().plot.bar(figsize=(21,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Categorical variable distributions

# %%
# Visualising GENRE_BOTA variable 
# print(df_trees['GENRE_BOTA'].value_counts())
df_trees['GENRE_BOTA'].value_counts().plot.bar(figsize=(21,10))
# Out:
# <AxesSubplot:>

# %%
# Visualising ESPECE variable 
# print(df_trees['ESPECE'].value_counts())
df_trees['ESPECE'].value_counts().plot.bar(figsize=(25,10))
# Out:
# <AxesSubplot:>

# %%
# Visualising GENRE_BOTA variable 
# print(df_trees['STADEDEDEVELOPPEMENT'].value_counts())
df_trees['STADEDEDEVELOPPEMENT'].value_counts().plot.bar(figsize=(21,10))
# Out:
# <AxesSubplot:>

# %%
# Visualising SOUS_CATEGORIE_DESC variable 
# print(df_trees['SOUS_CATEGORIE_DESC'].value_counts())
df_trees['SOUS_CATEGORIE_DESC'].value_counts().plot.bar(figsize=(21,10))
# Out:
# <AxesSubplot:>

# %%
# Visualising SOUS_CATEGORIE_DESC variable 
# print(df_trees['ADR_SECTEUR'].value_counts())
df_trees['ADR_SECTEUR'].value_counts().plot.bar(figsize=(21,10))
# Out:
# <AxesSubplot:>

# %%
# Visualising SOUS_CATEGORIE_DESC variable 
# print(df_trees['COLLECTIVITE'].value_counts())
df_trees['COLLECTIVITE'].value_counts().plot.bar(figsize=(21,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Relation between numerical variables

# %%
# relation between numerical variables 
sns.heatmap(df_trees.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Relation between target and other variables

# %%
sns.boxplot(x='COLLECTIVITE', y='ANNEEDEPLANTATION', data=df_trees)
# Out:
# <AxesSubplot:xlabel='COLLECTIVITE', ylabel='ANNEEDEPLANTATION'>

# %% [markdown]
# ## TO PICKLE DATA FRAME

# %%
# to pickle data frame
df_trees.to_pickle('./df_trees.pkl')
